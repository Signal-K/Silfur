# %%
# Install the lightkurve module in your env
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install lightkurve

# %%
from lightkurve import search_targetpixelfile
from lightkurve import TessTargetPixelFile
import lightkurve as lk
import numpy as np
# Out:
# Bad pipe message: %s [b'c\x14\xd8%\xb3y^%\x1a\xf0\x00\x13\x87\xa8\xb7\xf8\x9e\xc1 \xe8\xa5=Xfk\x00\x0e\r\x17\x12\x90\xa1\x9bwN\x04\x99\xd8\x96I\xed9Y\xf0\xef_sqB\xe7\x9c\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00']
# Bad pipe message: %s [b'\x03\x04']
# ...

# %%
# Download pixelfile for a star
#pixelFile = search_targetpixelfile('Star NAME', author='Kepler', cadence='long', quarter=4).download()
pixelFile = search_targetpixelfile('KIC 6922244', author='Kepler', cadence='long', quarter=4).download()

# %%
"""
State variables (for api integration):
period
planetName
author
star
cadence
quarter
frame

panoptes-api: https://github.com/panoptes/lightcurve-demo
Now the next thing to look at is getting this to work with other data sets to retrieve information about other object formats (e.g. planets in the solar system)
"""

# %% [markdown]
# # A/B Testing

# %% [markdown]
# This notebook visualizes and measures the results of an A/B test.

# %%
# %matplotlib notebook

#!pip install lightkurve
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install lightkurve
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install seaborn

import matplotlib.pyplot as plt
import lightkurve as lk
# Out:
# Requirement already satisfied: numpy in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (1.23.3)
# Requirement already satisfied: lightkurve in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: memoization>=0.3.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (0.4.0)
# Requirement already satisfied: matplotlib>=3.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (3.6.0)
# Requirement already satisfied: numpy>=1.18 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (1.23.3)
# Requirement already satisfied: urllib3>=1.23 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (1.26.12)
# Requirement already satisfied: tqdm>=4.25.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (4.64.1)
# Requirement already satisfied: requests>=2.22.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (2.28.1)
# Requirement already satisfied: patsy>=0.5.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (0.5.2)
# Requirement already satisfied: fbpca>=1.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (1.0)
# Requirement already satisfied: astroquery>=0.3.10 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (0.4.6)
# Requirement already satisfied: scipy>=1.7 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (1.9.1)
# Requirement already satisfied: bokeh>=1.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (2.4.3)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (4.11.1)
# Requirement already satisfied: astropy>=5.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (5.1)
# Requirement already satisfied: oktopus>=0.1.2 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (0.1.2)
# Requirement already satisfied: pandas>=1.1.4 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (1.5.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (3.1.7)
# Requirement already satisfied: scikit-learn>=0.24.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from lightkurve) (1.1.2)
# Requirement already satisfied: packaging>=19.0 in /home/codespace/.local/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (21.3)
# Requirement already satisfied: pyerfa>=2.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (2.0.0.1)
# Requirement already satisfied: PyYAML>=3.13 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from astropy>=5.0->lightkurve) (6.0)
# Requirement already satisfied: pyvo>=1.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (1.3)
# Requirement already satisfied: keyring>=4.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (23.9.3)
# Requirement already satisfied: html5lib>=0.999 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from astroquery>=0.3.10->lightkurve) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.3.2.post1)
# Requirement already satisfied: pillow>=7.1.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (9.2.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (4.3.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in /home/codespace/.local/lib/python3.10/site-packages (from bokeh>=1.1->lightkurve) (6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (4.37.3)
# Requirement already satisfied: cycler>=0.10 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Requirement already satisfied: autograd in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from oktopus>=0.1.2->lightkurve) (1.4)
# Requirement already satisfied: pytz>=2020.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from pandas>=1.1.4->lightkurve) (2022.2.1)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from patsy>=0.5.0->lightkurve) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from requests>=2.22.0->lightkurve) (2022.9.14)
# Requirement already satisfied: joblib>=1.0.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from scikit-learn>=0.24.0->lightkurve) (3.1.0)
# Requirement already satisfied: future in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from uncertainties>=3.1.4->lightkurve) (0.18.2)
# Requirement already satisfied: webencodings in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=1.1->lightkurve) (2.1.1)
# Requirement already satisfied: SecretStorage>=3.2 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.3.3)
# Requirement already satisfied: jaraco.classes in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.2.2)
# Requirement already satisfied: jeepney>=0.4.2 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (0.8.0)
# Requirement already satisfied: cryptography>=2.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from SecretStorage>=3.2->keyring>=4.0->astroquery>=0.3.10->lightkurve) (38.0.1)
# Requirement already satisfied: more-itertools in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from jaraco.classes->keyring>=4.0->astroquery>=0.3.10->lightkurve) (8.14.0)
# Requirement already satisfied: cffi>=1.12 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=4.0->astroquery>=0.3.10->lightkurve) (1.15.1)
# Requirement already satisfied: pycparser in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=4.0->astroquery>=0.3.10->lightkurve) (2.21)
# Requirement already satisfied: matplotlib in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.19 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib) (4.37.3)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: matplotlib>=3.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from seaborn) (3.6.0)
# Requirement already satisfied: pandas>=0.25 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from seaborn) (1.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from matplotlib>=3.1->seaborn) (4.37.3)
# Requirement already satisfied: pytz>=2020.1 in /home/linuxbrew/.linuxbrew/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)

# %% [markdown]
# ## Star selection

# %%
TIC = 'TIC 284475976' # TIC Star ID
sector_data = lk.search_lightcurve(TIC, author = 'SPOC', sector = 23) # can remove each arg if needed
sector_data
lc = sector_data.download()
lc.plot()
# Out:
# <div id='d9f16a67-d1a1-44fa-9720-4b76c6a76ffd'></div>
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc.plot(linewidth = 0, marker = '.', color = 'lightcyan', alpha = 0.3)
# Out:
# <div id='0f9278a2-6c8d-4de4-aa4b-9e52876bb83d'></div>
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
# Plotting from multiple sectors
TIC_2 = 'TIC 55525572'
available_data_all = lk.search_lightcurve(TIC_2, author = 'SPOC')
available_data_all
# Out:
# SearchResult containing 24 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 04 2018   SPOC     120    55525572      0.0
#   1 TESS Sector 05 2018   SPOC     120    55525572      0.0
#   2 TESS Sector 06 2018   SPOC     120    55525572      0.0
#   3 TESS Sector 08 2019   SPOC     120    55525572      0.0
#   4 TESS Sector 09 2019   SPOC     120    55525572      0.0
#   5 TESS Sector 10 2019   SPOC     120    55525572      0.0
#   6 TESS Sector 11 2019   SPOC     120    55525572      0.0
#   7 TESS Sector 12 2019   SPOC     120    55525572      0.0
#   8 TESS Sector 13 2019   SPOC     120    55525572      0.0
#   9 TESS Sector 27 2020   SPOC      20    55525572      0.0
# ...            ...  ...    ...     ...         ...      ...
#  14 TESS Sector 30 2020   SPOC     120    55525572      0.0
#  15 TESS Sector 31 2020   SPOC     120    55525572      0.0
#  16 TESS Sector 32 2020   SPOC     120    55525572      0.0
#  17 TESS Sector 33 2020   SPOC     120    55525572      0.0
#  18 TESS Sector 34 2021   SPOC     120    55525572      0.0
#  19 TESS Sector 35 2021   SPOC     120    55525572      0.0
#  20 TESS Sector 36 2021   SPOC     120    55525572      0.0
#  21 TESS Sector 37 2021   SPOC     120    55525572      0.0
#  22 TESS Sector 38 2021   SPOC     120    55525572      0.0
#  23 TESS Sector 39 2021   SPOC     120    55525572      0.0
# Length = 24 rows

# %%
select_sector = available_data_all[0:4]
select_sector
# Out:
# SearchResult containing 4 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 04 2018   SPOC     120    55525572      0.0
#   1 TESS Sector 05 2018   SPOC     120    55525572      0.0
#   2 TESS Sector 06 2018   SPOC     120    55525572      0.0
#   3 TESS Sector 08 2019   SPOC     120    55525572      0.0

# %%
lc_collection = select_sector.download_all() # download all the sectors ([0:4])
lc_collection
# Out:
# LightCurveCollection of 4 objects:
#     0: <TessLightCurve LABEL="TIC 55525572" SECTOR=4 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     1: <TessLightCurve LABEL="TIC 55525572" SECTOR=5 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     2: <TessLightCurve LABEL="TIC 55525572" SECTOR=6 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#     3: <TessLightCurve LABEL="TIC 55525572" SECTOR=8 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>

# %%
lc_collection.plot(linewidth = 0, marker = '.')
# Out:
# <div id='6af40d5c-1348-4f1d-a317-8b2ff7383753'></div>
# <AxesSubplot: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# Some simple ideas/notes very briefly:

# %% [markdown]
# 1. Move the plot into an interactive format (like a Zooniverse frontend fork) and look at where users "click" on "curves", save that to a DB

# %% [markdown]
# undefined. Connect DeepNote to Umbrel?

# %%
visits = _deepnote_execute_sql("""select
    visits.user_id,
    visits.visited_at,
    users.signed_up_at,
    users_ab.variant
from
    visits
    left join users on visits.user_id = users.user_id
    inner join users_ab on visits.user_id = users_ab.user_id
""", 'SQL_26D1FA15_65F7_4B77_8193_83C3976930E2')
visits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 visits = _deepnote_execute_sql("""select
#       2     visits.user_id,
#       3     visits.visited_at,
#       4     users.signed_up_at,
#       5     users_ab.variant
#       6 from
#       7     visits
#       8     left join users on visits.user_id = users.user_id
#       9     inner join users_ab on visits.user_id = users_ab.user_id
#      10 """, 'SQL_26D1FA15_65F7_4B77_8193_83C3976930E2')
#      11 visits
#
# NameError: name '_deepnote_execute_sql' is not defined

# %% [markdown]
# ## Conversion Rate

# %% [markdown]
# We need to check whether one variant resulted in a higher conversion rate than another. Let's start with a time series.

# %%
visits['registered'] = visits.signed_up_at.notna()
visits = visits.sort_values('visited_at').drop_duplicates('user_id',keep='first').copy()

conversion = visits.copy()
conversion['week'] = conversion.visited_at.dt.tz_localize(None).dt.to_period('W').dt.to_timestamp()
conversion = conversion.groupby(['variant','week']).registered.value_counts(normalize=True,dropna=False).reset_index(name='conversion')
conversion = conversion.loc[conversion.registered == True]

# %%
_deepnote_run_altair(conversion, """{"data":{"name":"placeholder"},"mark":{"type":"line","tooltip":{"content":"data"}},"height":220,"$schema":"https://vega.github.io/schema/vega-lite/v4.json","autosize":{"type":"fit"},"encoding":{"x":{"sort":null,"type":"temporal","field":"week","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"conversion","scale":{"type":"linear","zero":false}},"color":{"sort":null,"type":"nominal","field":"variant","scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %% [markdown]
# Here is the overall conversion rate for each variant:

# %%
conversion.groupby('variant').conversion.mean().reset_index(name='conversion_rate')
# Out:
#      variant  conversion_rate
# 0  variant_a         0.008130
# 1  variant_b         0.013527

# %% [markdown]
# ### Significance Test

# %% [markdown]
# It looks like Variant B has a higher conversion rate than Variant A. We need to make sure these results are significant.

# %%
from scipy.stats import chi2_contingency

# Calculate the proportion of registered users for variant A vs B
proportions = visits.groupby('variant').registered.value_counts(dropna=False).reset_index(name='nusers')
proportions = proportions.pivot(index='variant',columns='registered',values='nusers')

# Chi-Square test
g,p,dof,expctd = chi2_contingency(proportions)

print(f'p-value is {p}')
if p < 0.05:
    print(f'The difference in Conversion Rate between Variants A and B is statistically significant.')
else:
    print(f'The difference in Conversion Rate between Variants A and B is NOT statistically significant.')
# Out:
# p-value is 4.536508742253485e-12
# The difference in Conversion Rate between Variants A and B is statistically significant.

# %% [markdown]
# ## Retention Rate

# %% [markdown]
# We also want to know whether one variant of the website results in higher retention than another variant. For this, let's look at the weekly sessions of our users.

# %%
sessions_weekly = _deepnote_execute_sql("""select
    sessions.user_id,
    date_trunc('week',users.signed_up_at) as signed_up_at_week,
    floor(extract('day' from session_started_at - signed_up_at)/7) as week, -- The number of weeks that passed since the user signed up
    users_ab.variant
from
    sessions
    left join users on sessions.user_id = users.user_id
    inner join users_ab on sessions.user_id = users_ab.user_id
""", 'SQL_26D1FA15_65F7_4B77_8193_83C3976930E2')
sessions_weekly
# Out:
#                                 user_id         signed_up_at_week  week  \
# 0      20730e99d00d466eb218cfecee852647 2021-09-27 00:00:00+00:00   4.0
# 1      5541a58e2e1f4cbdafc9c1b12535f2d9 2021-07-12 00:00:00+00:00  14.0
# 2      5541a58e2e1f4cbdafc9c1b12535f2d9 2021-07-12 00:00:00+00:00   8.0
# 3      5541a58e2e1f4cbdafc9c1b12535f2d9 2021-07-12 00:00:00+00:00   8.0
# 4      5541a58e2e1f4cbdafc9c1b12535f2d9 2021-07-12 00:00:00+00:00   8.0
# ...                                 ...                       ...   ...
# 14240  b6d3a798e7a24dfc8ee996817824d101 2021-07-05 00:00:00+00:00   9.0
# 14241  2c3fede222b54a4e8c6181a42ed8c3a1 2021-08-16 00:00:00+00:00   5.0
# 14242  afe8126a93a2473e8458b77a911344fc 2021-08-30 00:00:00+00:00   4.0
# 14243  cbd0ebd955014ee8a6f879ff5aaf166f 2021-07-26 00:00:00+00:00   8.0
# 14244  62add97756664eb3b92552657690f55f 2021-08-09 00:00:00+00:00   0.0
#
#          variant
# 0      variant_b
# 1      variant_b
# 2      variant_b
# 3      variant_b
# 4      variant_b
# ...          ...
# 14240  variant_b
# 14241  variant_b
# 14242  variant_b
# 14243  variant_b
# 14244  variant_b
#
# [14245 rows x 4 columns]

# %%
import pandas as pd

def get_retention(df):
    retention = df.copy()

    # Save the cohort size before we start calculating retention
    cohort_size = retention.groupby(['signed_up_at_week']).user_id.nunique().reset_index(name='cohort_size')

    # For each cohort-week, calculate the number of users who visited
    retention = retention.groupby(['signed_up_at_week','week']).user_id.nunique().reset_index(name='n_users')

    # Pivot and melt the table. This is a little trick that allows us to add rows during weeks where a cohort was not active.
    retention = retention.pivot(index=['signed_up_at_week'],columns='week',values='n_users').fillna(0)
    retention = retention.melt(value_name='n_users',ignore_index=False).reset_index()

    # If part of the cohort is still not finished the week, then exclude that cohort-week from the data
    # To do this we add 6 days to the sign up date. This gives us the last sign ups of that cohort.
    retention = retention.loc[
        ~(retention.signed_up_at_week + pd.to_timedelta(retention.week + 1,'W') + pd.Timedelta(6,'D') >
        pd.Timestamp.now(tz='UTC').floor('D'))
    ]

    # Divide by the cohort size to get a percentage
    retention = retention.merge(cohort_size,on=['signed_up_at_week'])
    retention['prop'] = retention.n_users / retention.cohort_size

    retention_avg = retention.groupby('week').prop.mean().reset_index()

    retention_avg = retention_avg.rename(columns = dict(
        prop='Retention',
        week='Week',
    ))

    return retention_avg

sessions_a = sessions_weekly.loc[sessions_weekly.variant == 'variant_a']
retention_a = get_retention(sessions_a)
retention_a['variant'] = 'variant_a'

sessions_b = sessions_weekly.loc[sessions_weekly.variant == 'variant_b']
retention_b = get_retention(sessions_b)
retention_b['variant'] = 'variant_b'

retention = pd.concat([retention_a,retention_b])

# %%
_deepnote_run_altair(retention, """{"data":{"name":"placeholder"},"mark":{"type":"line","tooltip":{"content":"data"}},"height":220,"$schema":"https://vega.github.io/schema/vega-lite/v4.json","autosize":{"type":"fit"},"encoding":{"x":{"sort":null,"type":"quantitative","field":"Week","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"Retention","scale":{"type":"linear","zero":false}},"color":{"sort":null,"type":"nominal","field":"variant","scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %% [markdown]
# Here is the Week-4 Retention for each variant.

# %%
retention.loc[retention.Week == 4][['variant','Retention']].reset_index(drop=True)
# Out:
#      variant  Retention
# 0  variant_a   0.176021
# 1  variant_b   0.377029

# %% [markdown]
# ### Significance Test

# %% [markdown]
# Once again, check that the difference in retention is significance.

# %%
from scipy.stats import ttest_ind

# Label all users who retained 4+ weeks later
users_retention = sessions_weekly.groupby(['user_id','variant']).apply(lambda x: x.week.max() >= 4).reset_index(name='retained')

# Calculate the proportion of retained users for variant A vs B
proportions = users_retention.groupby('variant').retained.value_counts(dropna=False).reset_index(name='nusers')
proportions = proportions.pivot(index='variant',columns='retained',values='nusers')

# Chi-Square test
g,p,dof,expctd = chi2_contingency(proportions)

print(f'p-value is {p}')
if p < 0.05:
    print(f'The difference in Retention between Variants A and B is statistically significant.')
else:
    print(f'The difference in Retention between Variants A and B is NOT statistically significant.')
# Out:
# p-value is 2.5434010296902054e-12
# The difference in Retention between Variants A and B is statistically significant.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b4c251b4-c11a-481e-8206-c29934eb75da' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
